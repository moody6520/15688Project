# %% [markdown]
# # Exploratory Analysis of Crime in Los Angeles
# #### Course 15688 Team Project, DI Mu, Xinrui Li, Yizhen Ma

# %% [markdown]
# # I. Backgroud and Question:
# <br>
# According to the national-wide crime statistics, the crime rate of the City of Los Angeles is 20 % higher than the national average. A large amount of crime number provides sufficient data for us to analyze the phenomena of crime.
# <br><br>
# Since the conclusion we want to get from this project is to generate some suggestions about avoiding crime based on the analysis results, we first start with following questions:
#
# - What is the relation between cumulative crime number and time of the crime?
# - What is the relation between crimes and the location?
# - Is there any relation between crime victims and income? If so, do these relations vary with respect to different type of crimes?
# - Do some types of crime correlated with specific type of crime?

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import seaborn as sys
import folium
from folium.plugins import MarkerCluster
from wordcloud import WordCloud
from geopy.geocoders import Nominatim
from uszipcode import SearchEngine
from sodapy import Socrata
np.random.seed(0)

# %% [markdown]
# # II. Data Collection

# %% [markdown]
# - use the api from https://data.lacity.org/A-Safe-City/Crime-Data-from-2010-to-Present/63jg-8b9z to get the crime data in LA from 2010 to 2017
# - use the api from https://data.ftb.ca.gov/California-Personal-Income-Tax/Personal-Income-Tax-Statistics-By-Zip-Code/mriu-wsxf to get the tax income data in LA.

# %%
## get crime data
def getCrmieData():
    client = Socrata("data.lacity.org", None)
    results = client.get("63jg-8b9z",limit= 3000000)

    # Convert to pandas DataFrame
    results_df = pd.DataFrame.from_records(results)
    return results_df
## get income data
def getIncomeData():
    client = Socrata("data.ftb.ca.gov", None)
    results = client.get("mriu-wsxf", limit=1000000)

    # Convert to pandas DataFrame
    results_df = pd.DataFrame.from_records(results)
    return results_df

# %% [markdown]
# ### Get data
# Method one use the api provided above and do some data cleaing. Since we need the zip code column to join the the two table together, we also clean the zipcode column.
# - convert the column name to upper case
# - remove some meaningless row in zip code.

# %% [markdown]
# As the data downloading process takes long time, so we save the dataframe to a local file for further reading.

# %%
# Call api above, it will take about 1 minutes to download data. 
crimeData = getCrmieData()
incomeData = getIncomeData()

crimeData = crimeData.to_csv("crime_data.csv")
incomeData = incomeData.to_csv("income_data.csv")

crimeData = pd.read_csv("crime_data.csv")
incomeData = pd.read_csv("income_data.csv")

crimeData.columns = [x.upper() for x in crimeData.columns]
incomeData.columns = [x.upper() for x in incomeData.columns]
combine = pd.read_csv("combine.csv")
incomeData = incomeData[incomeData["ZIP_CODE"] != "Suppressed" ] 
incomeData = incomeData[incomeData["ZIP_CODE"] != "Suppressed1" ] 
incomeData = incomeData[incomeData["ZIP_CODE"] != "Unallocated" ] 
incomeData = incomeData[incomeData["ZIP_CODE"] != "Unallocated2" ] 
incomeData['ZIP_CODE'] = incomeData['ZIP_CODE'].astype(int)

# %%
incomeData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61451 entries, 0 to 61502
# Data columns (total 17 columns):
# UNNAMED: 0                     61451 non-null int64
# TAXABLE_YEAR                   61451 non-null int64
# ZIP_CODE                       61451 non-null int64
# STATE                          61451 non-null object
# CITY                           61451 non-null object
# COUNTY                         61451 non-null object
# RETURNS                        61451 non-null int64
# CA_AGI                         61451 non-null int64
# TOTAL_TAX_LIABILITY            61451 non-null int64
# COUNTYLATITUDE                 61446 non-null float64
# COUNTYLONGITUDE                61446 non-null float64
# GEO_COUNTY                     61446 non-null object
# GEO_CITY                       61418 non-null object
# :@COMPUTED_REGION_FS3R_2BK8    61446 non-null float64
# :@COMPUTED_REGION_8XKY_9GPE    56906 non-null float64
# GEO_ZIPCODE                    60427 non-null object
# ...

# %% [markdown]
# In order to combine these data together, we want to use the zip code to do this. The crime table contains the latitude and longitude of where the crime happens, and the tax table contains the tax income for each zip code in LA. So we need to figure out a way to translate a coordinate (lat and long) to a zip code.
#
# First, we try geopy library, which is a library to locate the coordinates of addresses, cities, countries, and landmarks across the globe. The detailed document can be found here (https://geopy.readthedocs.io/en/stable/)
#
# So for every row in the crime data, we get the latitude and lontitude and send a request to the geo server. The return is in a JSON format, we extract the postcode from it, and add a new column for the zip code.

# %% [markdown]
# The problem here is that it only supports around 50 requests per hour, but out dataset is around 2 million rows, so it is impossible for us to do it in this way.
#
# Then we found another zipcode library which is called uszipcode, it is a powerful and easy to use programmable zip code database in Python. So for the provided latitude and longitude, we use the search engine it provided and find the nearest zipcode for this coordinate. There will be some bias for this because the area of one zip code is not a regular shape, so the zip code the coordinate belongs to may not be its nearest zipcode. But for now, we just use this and see if it works.

# %% [markdown]
# # III. Visualization and Analysis
# <br>
#
# ## a. Crime Number vs. Time
# First, we generated the histogram of cumulative crime number in the database annually and monthly, in the first row of plots. <br>
# Since some years have 356 days while some have 366 and the data is cumulated to the end of November 2019, we normalized the annual crime number by the day number of year, respectively. Similarly, there are different day number in each month, we also normalized the count by the day number of months.

# %%
crimeData["DATE_OCC"] = pd.to_datetime(crimeData['DATE_OCC'])
crimeData['YEAR']=crimeData["DATE_OCC"].dt.year
crimeData['MONTH']=crimeData['DATE_OCC'].dt.month
crimeData['Day_of_Week']=crimeData['DATE_OCC'].apply(lambda x:x.weekday())
crimeData['HOUR']=crimeData['TIME_OCC']//100

# %%
y=crimeData.groupby("YEAR").count()['DR_NO']
y_d=[365,365,366,365,365,365,366,365,365,334]
anual=y/y_d
m=crimeData.groupby("MONTH").count()['DR_NO']
m_d=[31,28,31,30,31,30,31,31,30,31,30,28]
monthly=m/m_d

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (18, 10))
anual.plot(kind='bar',color='lightblue', ax = axes[0,0] )
axes[0,0].set_title("Number of crimes")
sns.countplot(crimeData["Day_of_Week"], color='lightgreen', ax = axes[1,0])
axes[1,0].set_title("Number of crimes")
monthly.plot(kind='bar', color = 'orange', ax = axes[0,1])
axes[0,1].set_title("Number of crimes")
sns.countplot(crimeData["HOUR"], color = 'orange', ax = axes[1,1])
axes[1,1].set_title("Number of crimes");

# %% [markdown]
# From the observation annually and monthly plot, 2016, 2017, and 2018 year have higher daily crime number while the crime number separated by month doesn't have noticeable difference.<br>
# Thus, we try to compare the crime number with respect to the day of the week and the hour of day.<br>
# (Note: the 0 to 6 indicate Monday to Sunday, ie, 4 is Friday)<br>
# From the second row of plots, we can tell that Friday usually have higher crime number and the 12 in the noon have significantly higher crime number than other time of day.

# %%
sns.heatmap(pd.pivot_table(data = crimeData, index = "Day_of_Week", 
                              columns = "HOUR", values = "DR_NO", aggfunc = 'count'), 
               cmap = 'Oranges');

# %% [markdown]
# Since the day of week and hour of day both have some information that we interested in, we further generated a heatmap with respect to both time types and it shows the results coincided with previous plots, that the Friday have generally higher crime number and the darkest part in the graph, which indicate the highest crime number is 12:00 Friday, and the second-highest is 12:00 Monday.

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (18, 7))
sns.heatmap(pd.pivot_table(data = crimeData[crimeData["CRM_CD"] ==110], index = "Day_of_Week", 
                              columns = "HOUR", values = "CRM_CD", aggfunc = 'count'), cmap = 'Reds', ax = axes[0])
axes[0].set_title("CRIMINAL HOMICIDE")
sns.heatmap(pd.pivot_table(data = crimeData[crimeData["WEAPON_USED_CD"] == 102], index = "Day_of_Week", 
                              columns = "HOUR", values = "WEAPON_USED_CD", aggfunc = 'count'), cmap = 'Reds', ax = axes[1])
axes[1].set_title("With HAND GUN");

# %% [markdown]
# The main reason we want to analysis the relation of crime with other factors is that we try to get some conclusive suggestion to help people avoid crime and since there are too many types of crime, only a few would jeopardize our personal safety, we focus our analysis on those type of crime first.<br>
# In the heatmap of criminal homicide, we notice that the most frequent time is Saturday midnight. Generally, weekends have a higher number of homicide comparing with workdays, especially in the night.<br>
# In the heatmap for the crime with the handgun, it shows that Saturday 23:00 to Sunday 1:00 are the period that has the most frequent crime with the handgun and generally more crime with the handgun in the night compared with daytime.

# %% [markdown]
# ## b. Crime Time Trend
# We want to see how the number of crime changes over time, the total number of crime goes up or down for recent years.
# Since the data is so large, we only focusing on the recent 5 years, from 2015 to 2019. Nov, we count the number of crimes by month.

# %%
# conver the type for date, from string toe datatime.
crimeData["DATE"] = pd.to_datetime(crimeData['DATE_OCC'])
timeOccurences = crimeData[["DATE","CRM_CD"]]

# only draw from 2015 to 2019
filterData = timeOccurences.set_index("DATE").loc['01/01/2015 12:00:00 AM':'12/31/2019 12:00:00 AM']

filterData.reset_index(inplace=True)
filterData['DATE'] = filterData['DATE'].map(lambda x:x.strftime("%Y-%m"))
print(filterData)
# Out:
#             DATE  CRM_CD
# 0        2015-04     510
# 1        2015-07     510
# 2        2015-10     510
# 3        2015-08     510
# 4        2015-02     510
# ...          ...     ...
# 1096789  2019-03     648
# 1096790  2019-08     331
# 1096791  2019-01     930
# 1096792  2019-10     420
# 1096793  2019-02     330
#
# [1096794 rows x 2 columns]

# %%
filterDataYearMonth = filterData.groupby('DATE').count()
fig = plt.figure(figsize=(18,6))

axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(filterDataYearMonth, 
          c = 'blue', label = "Original data")
plt.xticks(rotation = 90)
plt.legend()
axes.set_title("Number of crimes every Month")
axes.set_ylabel("Number of crimes")
# Out:
# Text(0, 0.5, 'Number of crimes')

# %% [markdown]
# Since the data is not complete for Nov. 2019, there may be a drop there.
# From the graph, we can see that in a long time window, the number of crimes change periodically and few crimes happend in February every year. The overall trend is constant.

# %% [markdown]
# Then we focus on a specific year in 2015, to see how the number of crimes changes each day.

# %%
filterData2015 = timeOccurences.set_index("DATE").loc['01/01/2015 12:00:00 AM':'12/31/2015 12:00:00 AM']
filterData2015.reset_index(inplace=True)
filterData2015Count = filterData2015.groupby('DATE').count()
print(filterData2015Count.sort_values(by=['DATE']))

fig = plt.figure(figsize=(18,6))

axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(filterData2015Count, 
          c = 'blue', label = "Original data")
plt.xticks(rotation = 90)
plt.legend()
axes.set_title("Number of crimes in 2015")
axes.set_ylabel("Number of crimes")
# Out:
#             CRM_CD
# DATE
# 2015-01-01    1429
# 2015-01-02     515
# 2015-01-03     495
# 2015-01-04     510
# 2015-01-05     629
# ...            ...
# 2015-12-27     502
# 2015-12-28     546
# 2015-12-29     514
# 2015-12-30     549
# 2015-12-31     625
#
# [365 rows x 1 columns]
# Text(0, 0.5, 'Number of crimes')

# %% [markdown]
# From the graph, we can see that the number of crimes is extremely high at the beginning of the year.
# And the number of crimes is periodic fluctuations, like an electrocardiogram. It is slightly high at every beginning of the month.

# %% [markdown]
# Then we focus on a specific crime type which is CRIMINAL HOMICIDE (crime id == 110).

# %%
# Filter out the data
filterData2015 = timeOccurences.set_index("DATE").loc['01/01/2015 12:00:00 AM':'12/31/2015 12:00:00 AM']
filterData2015.reset_index(inplace=True)
killingData = filterData2015[filterData2015["CRM_CD"] == 110]
killingData1 = killingData[["DATE","CRM_CD"]].groupby('DATE').count()
print(killingData1)
# Out:
#             CRM_CD
# DATE
# 2015-01-01       1
# 2015-01-02       1
# 2015-01-03       1
# 2015-01-04       2
# 2015-01-06       1
# ...            ...
# 2015-12-22       2
# 2015-12-25       1
# 2015-12-27       1
# 2015-12-29       1
# 2015-12-30       1
#
# [188 rows x 1 columns]

# %%
fig = plt.figure(figsize=(18,6))
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(killingData1, 
          c = 'lightblue', label = "Original data")
plt.xticks(rotation = 90)
plt.legend()
axes.set_title("Kill crimes in 2015")
axes.set_ylabel("Number of crimes with Killing")
# Out:
# Text(0, 0.5, 'Number of crimes with Killing')

# %% [markdown]
# There are not that many homicides every day in 2015, on average around 3 every day in LA.

# %% [markdown]
# Then, let us see how it goes for every month in a larger time range.

# %%
crimeData["DATE"] = pd.to_datetime(crimeData['DATE_OCC'])
timeOccurences = crimeData[["DATE","CRM_CD"]]

# only draw from 2015 to 2019
filterData = timeOccurences.set_index("DATE").loc['01/01/2015 12:00:00 AM':'12/31/2019 12:00:00 AM']

filterData.reset_index(inplace=True)
filterData['DATE'] = filterData['DATE'].map(lambda x:x.strftime("%Y-%m"))
killingData = filterData[filterData["CRM_CD"] == 110]
print(filterData)

fig = plt.figure(figsize=(18,6))

axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(killingData.groupby('DATE').count(), 
          c = 'blue', label = "Original data",marker = "o")
plt.xticks(rotation = 90)
plt.legend()
axes.set_title("Killing Crimes every month")
axes.set_ylabel("Number of crimes")
# Out:
#             DATE  CRM_CD
# 0        2015-04     510
# 1        2015-07     510
# 2        2015-10     510
# 3        2015-08     510
# 4        2015-02     510
# ...          ...     ...
# 1096789  2019-03     648
# 1096790  2019-08     331
# 1096791  2019-01     930
# 1096792  2019-10     420
# 1096793  2019-02     330
#
# [1096794 rows x 2 columns]
# Text(0, 0.5, 'Number of crimes')

# %% [markdown]
# ## a. Crime Number vs. Location

# %% [markdown]
# Now we can move to space dimension now and analyze the security in districts. We have created two scatter plots to analyze the crime distribution for all crimes and homicide crime during the 10 years. The density degree of the first plot illustrates that most districts comparable number of crimes in the past 10 years while some places are much safer. And there is obvious color duplication on the boundary of different districts which indicates high possibility of crime incidents occurring. Also, we can see that there are small holes between some districts caused by the geological structure of Los Angeles with forests and mountains.
#
# For the right scatter plot, the number of homicide crime only takes up a small portion of all crime categories.One interesting thing is the districts with more frequent homicide crimes are not the places with more concentrated crimes of all categories illustrated by the plot. And the homicide crimes mainly spread over five adjacent districts while there is some sparse distribution in other areas.

# %%
data = crimeData[["DR_NO", "AREA","AREA_NAME", "DATE_OCC", "CRM_CD","LAT", "LON","YEAR"]].dropna()

# %%
# security measurement (This figure will take long time to draw! Be Careful to run!)
fig, axes = plt.subplots(1,2, figsize = (18,7))
data.LAT.replace(0, None, inplace=True)
data.LON.replace(0, None, inplace=True)

kill_data = data[data["CRM_CD"] == 110]
data.sort_values(by=['AREA_NAME'], inplace=True)
kill_data.sort_values(by=["AREA_NAME"], inplace=True)
# all crime over 10 years location distribution
sys.scatterplot(x = "LAT",  y= "LON", hue = "AREA_NAME", alpha= 0.01, data = data, ax = axes[0])
# kill crime over 10 year location distribution
sys.scatterplot(x = "LAT",  y= "LON", hue = "AREA_NAME", alpha= 0.10, data = kill_data, ax = axes[1])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Let's find the homicide crime incidents!

# %%
map_data = crimeData[["DR_NO","AREA", "CRM_CD","LON", "LAT"]]
map_data = map_data[map_data["CRM_CD"]==110]

# %% [markdown]
# We also plot the number of homicide crimes on google maps to acquire a more direct visualization and you can interact with the map. The homicide crimes mainly occurs in the center area of Los Angeles.

# %%
start_lat, start_long = map_data["LAT"].mean(), map_data["LON"].mean()
map_sample = folium.Map(location = [map_data["LAT"].mean(), map_data['LON'].mean()])
mark = MarkerCluster()
for row in map_data.itertuples():
    mark.add_child(folium.Marker(location = [row.LAT, row.LON]))
map_sample.add_child(mark)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # IV. Correlations
# <br>
#
# ## a. Crime correlation

# %% [markdown]
# Given 141 types of crime, we selected four frequent types: Theft, Robbery, Rape, and Children Abuse.<br>
# - Theft:<br>
#     * Code: 442 -- SHOPLIFTING - PETTY THEFT
#     * Code: 331 -- THEFT FROM MOTOR VEHICLE - GRAND
#     * Code: 420 -- THEFT FROM MOTOR VEHICLE - PETTY
#     * Code: 440 -- THEFT PLAIN
# <br><br>
# - Robbery: Code: 210<br>
# <br>
# - Murder: Code: 110<br>
# <br>
# - Children Abuse:<br>
#     * Code: 627 -- CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT
#     * Code: 235 -- CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT

# %%
crimeCodeDict = crimeData[["CRM_CD","CRM_CD_DESC"]].set_index("CRM_CD").to_dict()
keys = crimeCodeDict['CRM_CD_DESC'].keys()
print('The number of crime type is', len(keys))
# Out:
# The number of crime type is 141

# %%
theaf=set([442,331,420,440])
rob=210
murder=110
ch_abuse=set([627,235])
filt=set([442,331,420,440,210,121,110,627,235,943])

# %% [markdown]
# We first plot is the co-occurred crime given a murder. It shows that the most frequent co-occurred crime is code: 648 -- Arson.

# %%
murd=crimeData[crimeData['CRM_CD']==murder]
fig, axes = plt.subplots(figsize = (18, 10))
murd2=(murd['CRM_CD_2'].append(murd['CRM_CD_3'])).append(murd['CRM_CD_4'])
murd2=murd2[murd2.isin(keys)]
test=murd2[murd2.isin(keys)]
sns.countplot(test, color='lightblue' )
axes.set_title("Given murder");

# %% [markdown]
# The second plot is the co-occurred crime given a theft happened. It shows that the most frequent co-occurred crime is code: 480 -- Bike stolen, indicating that the bike is stolen most often.

# %%
thee=crimeData[crimeData['CRM_CD'].isin(theaf)]

fig, axes = plt.subplots(figsize = (18, 10))

thee2=(thee['CRM_CD_2'].append(thee['CRM_CD_3'])).append(thee['CRM_CD_4'])
thee2=thee2[thee2.isin(keys)]
sns.countplot(thee2, color='lightgreen')
axes.set_title("Given theaf")
plt.xticks(rotation=45);

# %% [markdown]
# The third plot is the co-occurred crime given a robbery happened. It shows that the most frequent co-occurred crime is code: 910 -- Kidnapping.

# %%
robery=crimeData[crimeData['CRM_CD']==rob]
fig, axes = plt.subplots(figsize = (18, 10))
robery2=(robery['CRM_CD_2'].append(robery['CRM_CD_3'])).append(robery['CRM_CD_4'])
robery2=robery2[robery2.isin(keys)]
sns.countplot(robery2, color = 'orange')
axes.set_title("Given robery")
plt.xticks(rotation=45);

# %% [markdown]
# The fourth plot is the co-occurred crime given a child abuse happened. It shows that the most frequent co-occurred crime is code: 812 -- Crime against a child under 13, which indicates that the child abuse happened most frequent toward the child under 13.

# %%
child=crimeData[crimeData['CRM_CD'].isin(ch_abuse)]
fig, axes = plt.subplots(figsize = (18, 10))

child2=(child['CRM_CD_2'].append(child['CRM_CD_3'])).append(child['CRM_CD_4'])
child2=child2[child2.isin(keys)]

sns.countplot(child2, color = 'orange')
axes.set_title("Given children abuse")
plt.xticks(rotation=45);

# %% [markdown]
# ## b. Crime vs. Income relation

# %%
tax_income_2014 = incomeData[incomeData["TAXABLE_YEAR"] == 2014]
merged = pd.merge(left=combine,right=tax_income_2014, left_on="ZIP_CODE", right_on='ZIP_CODE',how="inner")
merged['Total Tax Liability']=merged['TOTAL_TAX_LIABILITY']//1000

# %% [markdown]
# We generated the heatmap of the total tax liability with respect to the crime type and tried to find out if income is a factor that affects the frequency of the specific type of crime.<br>
# The results show that the income strongly affect two types of crime: ROBBERY and THEFT PLAIN.<br>
# For the robbery, it happened more often in the low-income area while the theft happened more often on the mid-income area.<br>

# %%
sns.heatmap(pd.pivot_table(data = merged, index = "TOTAL_TAX_LIABILITY", 
                              columns = "Crm Cd", values = "DR_NO", aggfunc = 'count'), cmap = 'Oranges');

# %% [markdown]
# ## c. Time Trend with tax income

# %% [markdown]
# We want to find whether they are a relationship between tax income and crime.
# Since the crime table is so large, it will spend days to join the two table together, so here we only focus on two specific crime type which is homicide and robbery.

# %%
seriousCrime = crimeData[crimeData["CRM_CD"] == 110]

# %% [markdown]
# The below code will take about one hour.
# we have done this before and save it as a CSV file called Seriescombine.csv.

# %%
# Map zipcode to crime incident district (Don't run as it will take over an hour)
def map_zip_code():
    search = SearchEngine(simple_zipcode=False)

    count = 0
    def test_zip(row):
        try:
            result = search.by_coordinates(row["LAT"], row["LON"], radius=10, returns=1)
            global count
            count = count + 1
            if count % 1000 == 0:
                print("finished 100")
            return result[0].zipcode
        except:
            result = -1
            return result

    seriousCrime["ZIP_CODE"] = seriousCrime.apply(test_zip, axis = 1)
    seriousCrime.to_csv("Seriescombine.csv")

# %% [markdown]
# Then, let's see if there is a relationship between tax income and the number of crimes in time.

# %%
seriesDF = pd.read_csv('./Seriescombine.csv')
seriesDF["DATE OCC"] = pd.to_datetime(seriesDF['DATE OCC'])
seriesDF['YEAR']=seriesDF["DATE OCC"].dt.year

# %%
killCrimeCombineTax = seriesDF.merge(incomeData, left_on=["YEAR","ZIP_CODE"], right_on=["TAXABLE_YEAR","ZIP_CODE"])

# %% [markdown]
# Now, for each crime, we have the zip code and the tax income for it.
# In order to see the relationship between this, we assume that there may be some differences between rich people and poor people. As the tax income goes up in some areas, the people in that area will become rich so it may lead to more crimes. However at the same time, the higher tax income may related t better public security, so it may lead to low crimes. We think there will be a difference between the rich and the poor.
#
# So first we sperate the area according to its average taxable income.

# %%
# Rich 
killCrimeCombineRichTax = killCrimeCombineTax[killCrimeCombineTax["RETURNS"] > 20000]

# Poor
killCrimeCombinePoorTax = killCrimeCombineTax[killCrimeCombineTax["RETURNS"] < 20000]

# %% [markdown]
# Now, let's draw the three graph, the overall, the rich and the poor, and see how it looks like.

# %%
def drawTaxCrimeTimeTrend(data,title):
    XYear = [i+2010 for i in range(8)]
    yIncome = data.groupby("YEAR").mean()["TOTAL_TAX_LIABILITY"].tolist()
    yCrimeCount = data.groupby("YEAR").count()["DATE OCC"].tolist()
    fig, income = plt.subplots()

    color = 'tab:red'
    income.set_xlabel('time (Year)')
    income.set_ylabel('Total Income', color=color)
    income.plot(XYear, yIncome, color=color)
    income.tick_params(axis='y', labelcolor=color)

    crimeCount = income.twinx()

    color = 'tab:blue'
    crimeCount.set_ylabel('Kill Crime Count', color=color)
    crimeCount.plot(XYear, yCrimeCount, color=color)
    crimeCount.tick_params(axis='y', labelcolor=color)
    income.set_title(title)
    fig.tight_layout()
    plt.show()
drawTaxCrimeTimeTrend(killCrimeCombineTax,"Killing-TaxIncome Time Trend")
drawTaxCrimeTimeTrend(killCrimeCombineRichTax,"Killing-TaxIncome Time Trend for Rich")
drawTaxCrimeTimeTrend(killCrimeCombinePoorTax,"Killing-TaxIncome Time Trend for Poor")

# %% [markdown]
# The x-axis is the time of year from 2010 to 2017, the red line is the total tax income in LA, and its axis is on the left-hand side. The blue line is the number of crime happened for homicide. As we can see from the first graph(the overall one), it is hard to say there's a relationship between the two, because as the tax income increase, many underlying factors may affect the number of crimes happed.
#
# However, if we divided the area into the rich and poor according to the average tax-income of that area. There is some relationship between these two. For the rich people graph, we found that the number of crimes for homicide is proportional to the tax income which means as the income goes up, the number of crimes also goes up. We think that, for rich areas, there is already a better public security comparing to the poor people. But as the tax income increases, there will be more rich people and that lead to the number of crime increase. While for the poor area which is shown in the third graph, the result is the opposite. The number of crimes for homicide is inversely proportional to the tax income. We assume that as the tax income goes up, this area has better public security, so the number of crimes will decrease.

# %% [markdown]
# Then, to verify our conclusion above, we change to another crime type which is robbery(crime code = 210). Because we think that robbery may have a stronger relationship with tax income.

# %%
RobCrime = crimeData[crimeData["CRM_CD"] == 210]

# %% [markdown]
# Also, use the same search engine we mentioned above to add the zip code column.
# This part of the code will take a long time for 2-3 hours. So we already do this and save the data as RobCrime.csv.

# %%
def map_rob_zip_code():
    search = SearchEngine(simple_zipcode=False)

    count = 0
    def test_zip(row):
        try:
            result = search.by_coordinates(row["LAT"], row["LON"], radius=10, returns=1)
            global count
            count = count + 1
            if count % 1000 == 0:
                print("finished 100")
            return result[0].zipcode
        except:
            result = -1
            return result

    RobCrime["ZIP_CODE"] = RobCrime.apply(test_zip, axis = 1)
    RobCrime.to_csv("RobCrime.csv")

# %%
RobCrime = pd.read_csv('RobCrime.csv')
RobCrime["DATE OCC"] = pd.to_datetime(RobCrime['DATE OCC'])
RobCrime['YEAR']=RobCrime["DATE OCC"].dt.year

# %%
RobCrimeCombimeTax = RobCrime.merge(incomeData, left_on=["YEAR","ZIP_CODE"], right_on=["TAXABLE_YEAR","ZIP_CODE"])

# Rich 
RobCrimeCombimeRichTax = RobCrimeCombimeTax[RobCrimeCombimeTax["RETURNS"] > 20000]

# Poor
RobCrimeCombimePoorTax = RobCrimeCombimeTax[RobCrimeCombimeTax["RETURNS"] < 15000]

# %%
def drawTaxCrimeTimeTrend(data,title):    
    XYear = [i+2010 for i in range(8)]

    yIncome = data.groupby("YEAR").mean()["TOTAL_TAX_LIABILITY"].tolist()
    yCrimeCount = data.groupby("YEAR").count()["DATE OCC"].tolist()

    fig, income = plt.subplots()

    color = 'tab:red'
    income.set_xlabel('time (Year)')
    income.set_ylabel('Total Income', color=color)
    income.plot(XYear, yIncome, color=color)
    income.tick_params(axis='y', labelcolor=color)

    crimeCount = income.twinx()

    color = 'tab:blue'
    crimeCount.set_ylabel('Robbery Crime Count', color=color)
    crimeCount.plot(XYear, yCrimeCount, color=color)
    crimeCount.tick_params(axis='y', labelcolor=color)
    income.set_title(title)

    fig.tight_layout()
    plt.show()

drawTaxCrimeTimeTrend(RobCrimeCombimeTax,"Robbery-TaxIncome Time Trend")
drawTaxCrimeTimeTrend(RobCrimeCombimeRichTax,"Robbery-TaxIncome Time Trend for Rich")
drawTaxCrimeTimeTrend(RobCrimeCombimePoorTax,"Robbery-TaxIncome Time Trend for Poor")

# %% [markdown]
# The graph above can perfectly match our conclusion above, in which the number of crimes for robbery is proportional to the tax income in the rich area, and is inversely proportional to the tax income in the poor area.

# %% [markdown]
# ## c. Crime rate with tax income

# %% [markdown]
# We also want to analyze the correlation between district tax income and crime rate, so we created a histogram for comparison with respect to different districts specified by zip code in Los Angeles. We sort the data descendingly by the column of average tax income. The blue bar represents the value of average tax income while the orange bar indicates the crime rate in the specific area. We can see that there is a negative correlation between these two attributes. The crime rate is much higher in the area with lower tax income as we can see the correlation is evident in the right part of the histogram with a low tax return. In the district with a higher tax return, we also can see occurring of higher crime rate. The crime happening in the rich area might be different from those in poor districts, which could be the reason that places with significant different returns have comparable crime rates.

# %%
loc_group = merged.groupby("ZIP_CODE")["DR_NO"].count()
# loc_group = loc_group.to_frame()
loc_group = loc_group/loc_group.sum()
merged_zip = loc_group.index.unique()
merge_return = tax_income_2014[tax_income_2014["ZIP_CODE"].isin(merged_zip)]
merge_return.sort_values(by='ZIP_CODE', ascending=False)
histo_data = pd.DataFrame({"ZIP_CODE": loc_group.index, "CRIME_COUNT": loc_group.values, "TAX_INCOME": merge_return["RETURNS"] })
fig = plt.figure(figsize = (22,7))

histo_data = histo_data.sort_values(by="TAX_INCOME", ascending=False)
width = 0.45
histo_data.index = histo_data["ZIP_CODE"]
ax = fig.add_subplot(111)
ax2 = ax.twinx()
histo_data.CRIME_COUNT.plot(kind='bar', color='orange', ax=ax2, width=width, position=1)
histo_data.TAX_INCOME.plot(kind='bar', color='lightblue', ax=ax, width=width, position=0);

# %% [markdown]
# # V. Conclusion
# From the overall results, we found that the crime trend, in general, is periodically fluctuated and unpredictable while there are some conclusive relations given some factors.<br>
# Based on the analysis of time and crime number, we find more killing crime on midnight weekend and probably need more police go on patrol during that time periods for the goal of deterrence.<br>
# Based on the analysis of location and crime, the central Los Angeles have worse security situation and if someone needs to go to central LA, we suggest he/she find some company.<br>
# Based on the analysis of income and crime, we suggest that the mid-class family enhance their home security system against theft. Also, for low-income areas, people need more attention to robbery.<br>

# %% [markdown]
# # VI. Future Work
# With more background analysis of each type of crime such as victim and suspects' age, gender and education situations, we may get more insight conclusion such as the relation between mentioned factors, while that information is limited in our dataset.<br>
# We may apply more analysis on the crime correlations by including more types of crime to considerations and may develop a directed graph based on the dependency of the different crime types.<br>
# Also, besides the income, there are many outside factors such as the distribution of police stations and population density, etc, which may affect the occurrence of crime. In our project, we tried to match the crime to the nearest police office and we didn't get any adequate results and we may try more advanced ways to relate the crime to the police station with the help of other datasets in future work. <br>
# With the more comprehensive analysis of the city of Los Angeles, we can also apply a similar analysis on other big cities such as New York, Chicago or Boston and see if the results are similar. What's more, we can try some countryside city crime data and try to find the difference between cities.

# %% [markdown]
# # VII. Reference
#
# - geopy document: https://geopy.readthedocs.io/en/stable/
# - uszipcode: https://pypi.org/project/uszipcode/
# - seaborn: https://seaborn.pydata.org/
# - folium: http://python-visualization.github.io/folium/
# - Crime Analysis Through Machine Learning:
# https://www.researchgate.net/publication/330475412_Crime_Analysis_Through_Machine_Learning
# - crime data: https://data.lacity.org/A-Safe-City/Crime-Data-from-2010-to-Present/63jg-8b9z
# - income tax data: https://data.ftb.ca.gov/California-Personal-Income-Tax/Personal-Income-Tax-Statistics-By-Zip-Code/mriu-wsxf
# - crime data api: https://crime-data-explorer.fr.cloud.gov/api
